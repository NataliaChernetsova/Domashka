# %%
import pandas as pd

# %% [markdown]
# # Задание 1

# %%
data = pd.read_csv('ratings.csv')
data.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
data[data['rating']==5.0]['movieId'].value_counts().head(1)
# Out:
# 318    153
# Name: movieId, dtype: int64

# %%
data2 = pd.read_csv('movies.csv')
data2.head()
data2[ (data2['movieId']==318) ]
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# # Задание 2

# %%
d = pd.read_csv('power.csv')
d.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
d['country'].isin(['Latvia', 'Lithuania', 'Estonia' ])
d['category'] == 4 | d['category'] == 12 | d['category'] == 21
d3 = d[(d2['year'] > 2004) & (d2['year'] < 2012) & d2['quantity'] > 0]
d4 = d3.groupby('country')['quantity'].sum()[1]
print(f'Cуммарное потребление стран Прибалтики: {d4}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-0801f77b9bae> in <module>
#       1 d1 = d['country'].isin(['Latvia', 'Lithuania', 'Estonia' ])
# ----> 2 d2 = d1['category'] == 4 | d1['category'] == 12 | d1['category'] == 21
#       3 d3 = d2[(d2['year'] > 2004) & (d2['year'] < 2012) & d2['quantity'] > 0]
#       4 d4 = d3.groupby('country')['quantity'].sum()[1]
#       5 print(f'Cуммарное потребление стран Прибалтики: {d4}')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
# ...

# %%
d1.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: country, dtype: bool

# %% [markdown]
# # Задание 3

# %%
import pandas as pd

# %%
import pymysql

# %%
table = pd.read_html('http://www.cbr.ru/currency_base/daily/')[0]
table
# Out:
#     Цифр. код Букв. код  Единиц                                    Валюта  \
# 0          36       AUD       1                      Австралийский доллар
# 1         944       AZN       1                     Азербайджанский манат
# 2          51       AMD     100                          Армянских драмов
# 3         933       BYN       1                         Белорусский рубль
# 4         975       BGN       1                            Болгарский лев
# 5         986       BRL       1                          Бразильский реал
# 6         348       HUF     100                       Венгерских форинтов
# 7         410       KRW    1000                      Вон Республики Корея
# 8         344       HKD      10                      Гонконгских долларов
# 9         208       DKK       1                             Датская крона
# 10        840       USD       1                                Доллар США
# 11        978       EUR       1                                      Евро
# ...
